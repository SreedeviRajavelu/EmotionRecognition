# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wesad-swell-binary-stress-best-model/WESAD_SWELL_BINARY_BEST_MODEL/best_model.joblib
# /kaggle/input/wesad-swell-binary-stress-best-model/WESAD_SWELL_BINARY_BEST_MODEL/selected_features.pkl
# /kaggle/input/stress/dataset/dataset description.pdf
# /kaggle/input/stress/dataset/papers/Schmidt et al. - 2018 - Introducing WESAD.pdf
# /kaggle/input/stress/dataset/papers/Koldijk et. al - 2018 - Detecting Work Stress.pdf
# /kaggle/input/stress/dataset/papers/Koldijk et al. - 2014 - The SWELL dataset.pdf
# /kaggle/input/stress/dataset/dataset/dataset description.pdf
# /kaggle/input/stress/dataset/dataset/papers/Schmidt et al. - 2018 - Introducing WESAD.pdf
# /kaggle/input/stress/dataset/dataset/papers/Koldijk et. al - 2018 - Detecting Work Stress.pdf
# /kaggle/input/stress/dataset/dataset/papers/Koldijk et al. - 2014 - The SWELL dataset.pdf
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/classification/unseen-wesad-classification-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/classification/unseen-wesad-classification-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/classification/unseen-wesad-classification-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/regression/unseen-wesad-regression-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/regression/unseen-wesad-regression-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/unseen/regression/unseen-wesad-regression-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/classification/wesad-chest-combined-classification-eda.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/classification/wesad-classification-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/classification/wesad-classification-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/classification/wesad-classification-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/regression/wesad-regression-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/regression/wesad-chest-combined-eda.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/regression/wesad-regression-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/wesad/combined/regression/wesad-regression-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/classification/unseen-swell-classification-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/classification/unseen-swell-classification-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/classification/unseen-swell-classification-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/regression/unseen-swell-regression-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/regression/unseen-swell-regression-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/unseen/regression/unseen-swell-regression-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/classification/combined-swell-classification-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/classification/combined-swell-classification-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/classification/combined-swell-classification-eda-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/classification/combined-swell-classification-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/regression/combined-swell-regression-eda-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/regression/combined-swell-regression-eda-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/regression/combined-swell-regression-eda-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/eda/swell/combined/regression/combined-swell-regression-eda-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/classification/unseen-wesad-classification-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/classification/unseen-wesad-classification-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/classification/unseen-wesad-classification-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/regression/unseen-wesad-regression-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/regression/unseen-wesad-regression-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/unseen/regression/unseen-wesad-regression-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/classification/wesad-classification-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/classification/wesad-classification-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/classification/wesad-chest-combined-classification-hrv.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/classification/wesad-classification-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/regression/wesad-regression-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/regression/wesad-chest-combined-hrv.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/regression/wesad-regression-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/wesad/combined/regression/wesad-regression-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/classification/unseen-swell-classification-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/classification/unseen-swell-classification-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/classification/unseen-swell-classification-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/regression/unseen-swell-regression-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/regression/unseen-swell-regression-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/unseen/regression/unseen-swell-regression-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/classification/combined-swell-classification-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/classification/combined-swell-classification-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/classification/combined-swell-classification-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/classification/combined-swell-classification-hrv-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/regression/combined-swell-regression-hrv-test-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/regression/combined-swell-regression-hrv-validation-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/regression/combined-swell-regression-hrv-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/datasets/hrv/swell/combined/regression/combined-swell-regression-hrv-train-dataset.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/SSSQ Label/cross-validation-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/SSSQ Label/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/condition label/cross-validation-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/condition label/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/SSSQ Label/validation/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/classification/semi-unseen/condition label/validation/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/feature selection/classification/SSSQ Label/selected features with subject Id.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/feature selection/classification/condition label/selected features with subject Id.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/feature selection/regression/selected features with subject Id.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/SSSQ/cross-validation-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/wesad/regression/semi-unseen/validation/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/NasaTLX Label/cross-validation-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/NasaTLX Label/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/NasaTLX Label/validation/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/Condition Label/cross-validation-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/Condition Label/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/Condition Label/validation/unseen-performance.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/920.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/0.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/800.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/1440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1040.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1000.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1080.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1600.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/880.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/560.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/760.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/640.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/680.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1400.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/440.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/720.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/160.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/80.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/40.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/960.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1320.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1360.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/240.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/480.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1120.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/520.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1280.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/840.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/1200.csv
# /kaggle/input/stress/dataset/dataset/2. final/results/docs/eda/swell/classification/semi-unseen/NasaTLX Label/validation/920.csv
# ...
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/wesad/semi-unseen/regression/wesad-hrv-regression/wesad-hrv-regression.png
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-condition label-classification/swell-hrv-condition label-classification.pdf
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-condition label-classification/swell-hrv-condition label-classification.png
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-condition label-classification/swell-hrv-condition label-classification.svg
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-condition label-classification/swell-hrv-condition label-classification.eps
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-NasaTLX Label-classification/swell-hrv-NasaTLX Label-classification.svg
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-NasaTLX Label-classification/swell-hrv-NasaTLX Label-classification.eps
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-NasaTLX Label-classification/swell-hrv-NasaTLX Label-classification.pdf
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/classification/swell-hrv-NasaTLX Label-classification/swell-hrv-NasaTLX Label-classification.png
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression.svg
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression.png
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression.eps
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression/swell-hrv-regression.svg
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression/swell-hrv-regression.png
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression/swell-hrv-regression.eps
# /kaggle/input/stress/dataset/2. final/results/plots/plots/hrv/swell/semi-unseen/regression/swell-hrv-regression/swell-hrv-regression.pdf
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S15.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S4.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S10.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S3.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S9.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S5.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S17.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S7.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S11.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S16.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S8.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S13.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S6.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S14.txt
# /kaggle/input/stress/dataset/0. interim/wesad/rri/S2.txt
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S4_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S9_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S2_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S8_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S11_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S7_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S14_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S16_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S13_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S15_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S17_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S10_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S3_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S5_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/Labels/S6_quest.csv
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S15.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S4.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S10.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S3.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S9.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S5.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S17.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S7.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S11.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S16.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S8.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S13.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S6.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S14.txt
# /kaggle/input/stress/dataset/0. interim/wesad/eda/S2.txt
# /kaggle/input/stress/dataset/0. interim/swell/rri/p15.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p14.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p2.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p5.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p18.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p19.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p12.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p1.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p23.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p22.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p16.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p21.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p3.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p25.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p13.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p20.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p24.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p6.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p9.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p10.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p4.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p17.csv
# /kaggle/input/stress/dataset/0. interim/swell/rri/p7.csv
# /kaggle/input/stress/dataset/0. interim/swell/labels/behavioral-labels.xlsx
# /kaggle/input/stress/dataset/0. interim/swell/eda/p15.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p14.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p2.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p5.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p18.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p19.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p12.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p1.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p22.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p16.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p21.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p3.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p25.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p13.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p20.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p24.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p6.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p9.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p10.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p4.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p11.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p17.csv
# /kaggle/input/stress/dataset/0. interim/swell/eda/p7.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S14.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S6.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S4.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S2.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S3.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S13.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S15.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S9.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S7.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S11.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S8.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S10.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S5.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S16.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/labeled/chest/S17.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S13.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S6.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S11.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S8.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S16.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S14.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S3.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S5.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S2.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S17.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S9.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S7.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S4.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S15.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/chest/S10.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S13.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S6.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S11.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S8.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S16.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S14.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S3.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S5.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S2.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S17.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S9.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S7.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S4.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S15.csv
# /kaggle/input/stress/dataset/1. processed/eda/wesad/raw/wrist/S10.csv
# /kaggle/input/stress/dataset/1. processed/eda/swell/p25.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p24.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p6.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p12.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p22.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p3.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p13.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p2.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p14.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p1.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p17.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p18.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p9.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p10.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p5.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p16.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p15.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p19.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p21.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p7.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p20.xlsx
# /kaggle/input/stress/dataset/1. processed/eda/swell/p4.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S14.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S6.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S4.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S2.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S3.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S13.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S15.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S9.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S7.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S11.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S8.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S10.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S5.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S16.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/labeled/chest/S17.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S14.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S6.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S4.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S2.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S3.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S13.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S15.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S9.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S7.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S11.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S8.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S10.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S5.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S16.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/wesad/raw/chest/S17.xlsx
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p14.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p2.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p5.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p18.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p19.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p12.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p1.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p23.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p22.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p16.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p21.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p3.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p25.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p13.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p20.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p24.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p6.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p9.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p10.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p4.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p17.csv
# /kaggle/input/stress/dataset/1. processed/hrv/swell/p7.csv

# %%
pip install mrmr_selection
# Out:
# Collecting mrmr_selection
#   Downloading mrmr_selection-0.2.8-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: category-encoders in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (2.6.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (3.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (1.4.0)
# Requirement already satisfied: pandas>=1.0.3 in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (2.2.2)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (1.11.4)
# Requirement already satisfied: polars>=0.12.5 in /opt/conda/lib/python3.10/site-packages (from mrmr_selection) (0.20.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.3->mrmr_selection) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.3->mrmr_selection) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.3->mrmr_selection) (2023.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from category-encoders->mrmr_selection) (0.14.1)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from category-encoders->mrmr_selection) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mrmr_selection) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->mrmr_selection) (2.1.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.1->category-encoders->mrmr_selection) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.9.0->category-encoders->mrmr_selection) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.3->statsmodels>=0.9.0->category-encoders->mrmr_selection) (3.1.1)
# Downloading mrmr_selection-0.2.8-py3-none-any.whl (15 kB)
# Installing collected packages: mrmr_selection
# Successfully installed mrmr_selection-0.2.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, KFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, classification_report
from scipy import signal
from sklearn import svm
from sklearn.datasets import make_classification
#The mRMR (Minimum Redundancy and Maximum Relevance) feature selection framework solves this problem by selecting the relevant
#features while controlling for the redundancy within the selected features.
import mrmr
from mrmr import mrmr_classif
import matplotlib.pyplot as plt
import pickle
import sklearn.metrics
import numpy as np
import pandas as pd
import random
import time

# Start the timer
start_time = time.time()

# %% [markdown]
# # Dataset : SWELL HRV

# %%
#data source - https://www.kaggle.com/datasets/qiriro/stress
#loading swell dataset
swell = pd.read_csv("/kaggle/input/stress/dataset/2. final/datasets/hrv/swell/combined/classification/combined-swell-classification-hrv-dataset.csv")
swell
# Out:
#             MEAN_RR    MEDIAN_RR        SDRR      RMSSD       SDSD  \
# 0       1183.843150  1181.251800  365.254690  16.232314  16.228591
# 1       1021.041857  1022.250750  100.521147  21.561202  21.561202
# 2        820.137142   836.800665  107.879842  17.077352  17.076497
# 3        716.399934   745.647205  127.779239  15.836261  15.835732
# 4        977.406611  1041.002800  361.240628  14.531204  14.521966
# ...             ...          ...         ...        ...        ...
# 391633   790.421530   794.457970   50.172724  11.029840  11.028626
# 391634   819.584353   832.239875  141.689319  14.689652  14.689246
# 391635   809.148374   808.486885   63.859615  13.886357  13.886357
# 391636  1001.883049  1033.107000  141.446770  17.956429  17.956289
# 391637   778.186980   724.357530  153.533010  12.112575  12.112571
#
#         SDRR_RMSSD         HR      pNN25     pNN50        SD1  ...  \
# 0        22.501702  58.411211  10.466667  1.400000  11.479176  ...
# 1         4.662131  59.350494  24.466667  2.000000  15.251160  ...
# 2         6.317130  74.687574  13.466667  0.600000  12.078936  ...
# 3         8.068776  86.920960  10.466667  0.600000  11.201290  ...
# 4        24.859649  73.062657   7.000000  1.333333  10.272008  ...
# ...            ...        ...        ...       ...        ...  ...
# 391633    4.548817  76.233611   2.200000  0.266667   7.801019  ...
# 391634    9.645519  75.479391   6.066667  1.466667  10.390332  ...
# 391635    4.598731  74.621671   7.066667  0.000000   9.822414  ...
# 391636    7.877222  61.249311  14.466667  1.333333  12.701251  ...
# 391637   12.675506  79.678193   4.733333  0.000000   8.567739  ...
#
#         KURT_SQUARE   HR_SQRT  MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF     HR_LF  \
# 0          0.139715  7.642723              2.419575e+06  1.233729  0.139544
# 1          0.144814  7.703927             -3.929102e+07  0.076401  0.032082
# 2          0.632315  8.642197             -3.469434e+06  0.076524  0.037580
# 3          0.468034  9.323141             -3.132061e+06  0.190040  0.091586
# 4          1.269579  8.547670              1.535559e+06  1.115494  0.159565
# ...             ...       ...                       ...       ...       ...
# 391633     1.023535  8.731186              3.411073e+06  0.185744  0.200779
# 391634     0.165808  8.687888             -6.636711e+06  0.247628  0.093403
# 391635     0.092308  8.638384              2.099751e+08  0.075939  0.063121
# 391636     0.316769  7.826194             -1.299594e+07  0.166404  0.051054
# 391637     0.093729  8.926264              2.168873e+08  0.489424  0.179741
#
#             HR_HF    HF_VLF  NasaTLX class  Condition Label  NasaTLX Label
# 0        2.164920  0.004441           high                2              2
# 1        8.862171  0.002541         medium                0              1
# 2        3.795796  0.013737            low                1              0
# 3        1.152694  0.015717            low                0              0
# 4        2.541186  0.005019         medium                1              1
# ...           ...       ...            ...              ...            ...
# 391633   2.994731  0.041512         medium                1              1
# 391634   3.016309  0.004722            low                0              0
# 391635   4.801703  0.017767            low                1              0
# 391636  12.142254  0.001985            low                1              0
# 391637   1.865973  0.015935            low                0              0
#
# [391638 rows x 69 columns]

# %%
#stressors: email interruptions (1) and time pressure (2)
#no stress:0
label1=pd.DataFrame(swell['Condition Label'].map({0: 0,1:1, 2: 1}))
label1
# Out:
#         Condition Label
# 0                     1
# 1                     0
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 391633                1
# 391634                0
# 391635                1
# 391636                1
# 391637                0
#
# [391638 rows x 1 columns]

# %%
# show all columns
swell.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'sampen', 'higuci', 'condition', 'subject_id', 'MEAN_RR_LOG',
#        'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG', 'RMSSD_REL_RR_LOG',
#        'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG', 'TP_LOG', 'LF_HF_LOG',
#        'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG', 'pNN50_LOG', 'SD1_LOG',
#        'KURT_YEO_JONSON', 'SKEW_YEO_JONSON', 'MEAN_REL_RR_YEO_JONSON',
#        'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX', 'HF_BOXCOX', 'SD1_BOXCOX',
#        'KURT_SQUARE', 'HR_SQRT', 'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF',
#        'HR_HF', 'HF_VLF', 'NasaTLX class', 'Condition Label', 'NasaTLX Label'],
#       dtype='object')

# %%
# identify all unique subject id's in the SWELL data
subject_id=swell['subject_id']
# drop any columns that will not be used as input features to the model training/testing
swell=swell.drop(columns=['subject_id','sampen', 'higuci','condition', 'NasaTLX class', 'Condition Label', 'NasaTLX Label'])
# add back subject id's
swell['subject_id']=subject_id

# %%
# add back output column
swell_x = pd.concat([swell, label1], axis=1)
swell_x.head()
# Out:
#        MEAN_RR    MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  1183.843150  1181.251800  365.254690  16.232314  16.228591   22.501702
# 1  1021.041857  1022.250750  100.521147  21.561202  21.561202    4.662131
# 2   820.137142   836.800665  107.879842  17.077352  17.076497    6.317130
# 3   716.399934   745.647205  127.779239  15.836261  15.835732    8.068776
# 4   977.406611  1041.002800  361.240628  14.531204  14.521966   24.859649
#
#           HR      pNN25     pNN50        SD1  ...   SD1_BOXCOX  KURT_SQUARE  \
# 0  58.411211  10.466667  1.400000  11.479176  ...    57.119810     0.139715
# 1  59.350494  24.466667  2.000000  15.251160  ...  7757.321073     0.144814
# 2  74.687574  13.466667  0.600000  12.078936  ...     0.629808     0.632315
# 3  86.920960  10.466667  0.600000  11.201290  ...     2.352294     0.468034
# 4  73.062657   7.000000  1.333333  10.272008  ...     2.467751     1.269579
#
#     HR_SQRT  MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF     HR_LF     HR_HF    HF_VLF  \
# 0  7.642723              2.419575e+06  1.233729  0.139544  2.164920  0.004441
# 1  7.703927             -3.929102e+07  0.076401  0.032082  8.862171  0.002541
# 2  8.642197             -3.469434e+06  0.076524  0.037580  3.795796  0.013737
# 3  9.323141             -3.132061e+06  0.190040  0.091586  1.152694  0.015717
# 4  8.547670              1.535559e+06  1.115494  0.159565  2.541186  0.005019
#
#    subject_id  Condition Label
# 0          24                1
# 1           4                0
# 2           2                1
# 3          19                0
# 4          25                1
#
# [5 rows x 64 columns]

# %%
# show number of samples per user
subject_id.value_counts()
# Out:
# subject_id
# 16    21502
# 6     20888
# 19    19920
# 14    19680
# 10    19680
# 12    19680
# 4     19440
# 2     19395
# 1     19179
# 17    18824
# 18    18603
# 5     18050
# 7     17571
# 21    16679
# 24    16080
# 13    16080
# 3     16015
# 9     15942
# 22    15269
# 25    14915
# 20    14759
# 23    13487
# Name: count, dtype: int64

# %% [markdown]
# # Dataset : WESAD Chest HRV

# %%
#data source -https://www.kaggle.com/datasets/qiriro/stress
wesad = pd.read_csv("/kaggle/input/stress/dataset/2. final/datasets/hrv/wesad/combined/classification/wesad-chest-combined-classification-hrv.csv")
wesad
# Out:
#            MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0       660.756625  657.242305   34.857082   7.408307   7.408129    4.705134
# 1       762.004543  769.028815  106.035926  13.591780  13.580221    7.801475
# 2       978.587122  973.028365   80.323113  20.318045  20.316451    3.953289
# 3       690.333891  669.548460   79.677822  15.173680  15.173087    5.251055
# 4       724.270331  721.597785   71.663062  13.580379  13.580370    5.276956
# ...            ...         ...         ...        ...        ...         ...
# 135645  626.514447  611.246385   50.848737   5.969682   5.938417    8.517829
# 135646  628.974014  620.689235   64.127172  12.297019  12.293382    5.214855
# 135647  589.926708  581.814135   51.445399  11.549705  11.541521    4.454261
# 135648  924.373882  930.926635   88.692462  11.467998  11.467912    7.733910
# 135649  894.722024  921.715890  113.509123  21.857273  21.855299    5.193197
#
#                 HR  pNN25  pNN50        SD1  ...  MEAN_RR_MEAN_MEAN_REL_RR  \
# 0        91.050077   1.75   0.00   5.244915  ...              1.092856e+07
# 1        80.267696   6.00   1.00   9.614723  ...             -1.039564e+06
# 2        61.720802  20.50   1.50  14.383937  ...             -3.073518e+06
# 3        87.996270   8.75   1.50  10.742463  ...             -4.341078e+06
# 4        83.637107   5.00   0.75   9.614828  ...              1.311140e+07
# ...            ...    ...    ...        ...  ...                       ...
# 135645   96.341521   0.00   0.00   4.204367  ...             -7.113930e+05
# 135646   96.344181   5.00   0.25   8.703647  ...              1.184777e+06
# 135647  102.423931   3.25   0.25   8.171334  ...             -8.792667e+05
# 135648   65.529308   5.50   0.00   8.119220  ...             -8.005780e+06
# 135649   68.293067  22.00   2.75  15.473433  ...              2.719018e+06
#
#           SD2_LF     HR_LF      HR_HF    HF_VLF  subject id  condition  \
# 0       0.134410  0.249678   7.068440  0.033515          13   baseline
# 1       0.125816  0.067484   5.971604  0.003921           9   baseline
# 2       0.069888  0.038281  10.945519  0.003154           4  amusement
# 3       0.094345  0.074014   2.435759  0.009692           8     stress
# 4       0.076385  0.063323   3.259253  0.014438           4     stress
# ...          ...       ...        ...       ...         ...        ...
# 135645  0.271071  0.363785  24.633242  0.006019           5     stress
# 135646  0.057490  0.061358   3.873768  0.028697          13     stress
# 135647  0.107559  0.152385   2.082405  0.121886          10     stress
# 135648  0.333801  0.174757   6.849003  0.002597           5   baseline
# 135649  0.071363  0.030502   3.087285  0.004963           8  amusement
#
#         SSSQ class  SSSQ Label  condition label
# 0           medium           1                0
# 1              low           0                0
# 2           medium           1                1
# 3              low           0                2
# 4           medium           1                2
# ...            ...         ...              ...
# 135645        high           2                2
# 135646      medium           1                2
# 135647         low           0                2
# 135648        high           2                0
# 135649        high           2                1
#
# [135650 rows x 67 columns]

# %%
# show WESAD columns
wesad.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'subject id', 'condition', 'SSSQ class', 'SSSQ Label',
#        'condition label'],
#       dtype='object')

# %%
# map subjects to respective id's
subject_id=pd.DataFrame(wesad['subject id'].map({2: 26,3:27, 4: 28,5: 29,6:30, 7: 31,8: 32,9:33, 10: 34,11: 35,13:36, 14: 37,15: 38,16:39, 17: 40}))
subject_id
# Out:
#         subject id
# 0               36
# 1               33
# 2               28
# 3               32
# 4               28
# ...            ...
# 135645          29
# 135646          36
# 135647          34
# 135648          29
# 135649          32
#
# [135650 rows x 1 columns]

# %%
# make name the same for output columns
wesad=wesad.rename(columns={"condition label":"Condition Label"})
wesad.columns
# Out:
# Index(['MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR',
#        'pNN25', 'pNN50', 'SD1', 'SD2', 'KURT', 'SKEW', 'MEAN_REL_RR',
#        'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR',
#        'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR', 'VLF', 'VLF_PCT',
#        'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF',
#        'HF_LF', 'MEAN_RR_LOG', 'MEAN_RR_SQRT', 'TP_SQRT', 'MEDIAN_REL_RR_LOG',
#        'RMSSD_REL_RR_LOG', 'SDSD_REL_RR_LOG', 'VLF_LOG', 'LF_LOG', 'HF_LOG',
#        'TP_LOG', 'LF_HF_LOG', 'RMSSD_LOG', 'SDRR_RMSSD_LOG', 'pNN25_LOG',
#        'pNN50_LOG', 'SD1_LOG', 'KURT_YEO_JONSON', 'SKEW_YEO_JONSON',
#        'MEAN_REL_RR_YEO_JONSON', 'SKEW_REL_RR_YEO_JONSON', 'LF_BOXCOX',
#        'HF_BOXCOX', 'SD1_BOXCOX', 'KURT_SQUARE', 'HR_SQRT',
#        'MEAN_RR_MEAN_MEAN_REL_RR', 'SD2_LF', 'HR_LF', 'HR_HF', 'HF_VLF',
#        'subject id', 'condition', 'SSSQ class', 'SSSQ Label',
#        'Condition Label'],
#       dtype='object')

# %%
# split WESAD data into predictors and response variables
X_wesad=wesad.iloc[:,0:-5]
y_wesad=wesad['Condition Label']

# %%
# add back subject id information
X_wesad['subject_id']=subject_id
X_wesad
# Out:
#            MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0       660.756625  657.242305   34.857082   7.408307   7.408129    4.705134
# 1       762.004543  769.028815  106.035926  13.591780  13.580221    7.801475
# 2       978.587122  973.028365   80.323113  20.318045  20.316451    3.953289
# 3       690.333891  669.548460   79.677822  15.173680  15.173087    5.251055
# 4       724.270331  721.597785   71.663062  13.580379  13.580370    5.276956
# ...            ...         ...         ...        ...        ...         ...
# 135645  626.514447  611.246385   50.848737   5.969682   5.938417    8.517829
# 135646  628.974014  620.689235   64.127172  12.297019  12.293382    5.214855
# 135647  589.926708  581.814135   51.445399  11.549705  11.541521    4.454261
# 135648  924.373882  930.926635   88.692462  11.467998  11.467912    7.733910
# 135649  894.722024  921.715890  113.509123  21.857273  21.855299    5.193197
#
#                 HR  pNN25  pNN50        SD1  ...  HF_BOXCOX  SD1_BOXCOX  \
# 0        91.050077   1.75   0.00   5.244915  ...   4.289257    2.184257
# 1        80.267696   6.00   1.00   9.614723  ...   2.969491   12.244642
# 2        61.720802  20.50   1.50  14.383937  ...   1.990193   23.732955
# 3        87.996270   8.75   1.50  10.742463  ...   8.200294    1.705186
# 4        83.637107   5.00   0.75   9.614828  ...   4.243693   13.758863
# ...            ...    ...    ...        ...  ...        ...         ...
# 135645   96.341521   0.00   0.00   4.204367  ...   1.522743    0.735339
# 135646   96.344181   5.00   0.25   8.703647  ...   6.237187    3.117222
# 135647  102.423931   3.25   0.25   8.171334  ...   6.535686    8.960535
# 135648   65.529308   5.50   0.00   8.119220  ...   2.716431    0.837748
# 135649   68.293067  22.00   2.75  15.473433  ...   6.257788    1.876440
#
#         KURT_SQUARE    HR_SQRT  MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF     HR_LF  \
# 0          4.784952   9.542016              1.092856e+07  0.134410  0.249678
# 1          0.698604   8.959224             -1.039564e+06  0.125816  0.067484
# 2          0.091510   7.856259             -3.073518e+06  0.069888  0.038281
# 3          0.037746   9.380633             -4.341078e+06  0.094345  0.074014
# 4          0.001501   9.145333              1.311140e+07  0.076385  0.063323
# ...             ...        ...                       ...       ...       ...
# 135645     8.048406   9.815372             -7.113930e+05  0.271071  0.363785
# 135646     0.099832   9.815507              1.184777e+06  0.057490  0.061358
# 135647     6.980853  10.120471             -8.792667e+05  0.107559  0.152385
# 135648     0.199777   8.095017             -8.005780e+06  0.333801  0.174757
# 135649     0.037396   8.263962              2.719018e+06  0.071363  0.030502
#
#             HR_HF    HF_VLF  subject_id
# 0        7.068440  0.033515          36
# 1        5.971604  0.003921          33
# 2       10.945519  0.003154          28
# 3        2.435759  0.009692          32
# 4        3.259253  0.014438          28
# ...           ...       ...         ...
# 135645  24.633242  0.006019          29
# 135646   3.873768  0.028697          36
# 135647   2.082405  0.121886          34
# 135648   6.849003  0.002597          29
# 135649   3.087285  0.004963          32
#
# [135650 rows x 63 columns]

# %%
#Notation: 0-baseline; 1-amusement; 2-stress)
label2=pd.DataFrame(y_wesad.map({1: 0,0:0, 2: 1}))
label2
# Out:
#         Condition Label
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     1
# ...                 ...
# 135645                1
# 135646                1
# 135647                1
# 135648                0
# 135649                0
#
# [135650 rows x 1 columns]

# %%
# add back condition labels
X_wesad = pd.concat([X_wesad, label2], axis=1)
X_wesad.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  660.756625  657.242305   34.857082   7.408307   7.408129    4.705134
# 1  762.004543  769.028815  106.035926  13.591780  13.580221    7.801475
# 2  978.587122  973.028365   80.323113  20.318045  20.316451    3.953289
# 3  690.333891  669.548460   79.677822  15.173680  15.173087    5.251055
# 4  724.270331  721.597785   71.663062  13.580379  13.580370    5.276956
#
#           HR  pNN25  pNN50        SD1  ...  SD1_BOXCOX  KURT_SQUARE   HR_SQRT  \
# 0  91.050077   1.75   0.00   5.244915  ...    2.184257     4.784952  9.542016
# 1  80.267696   6.00   1.00   9.614723  ...   12.244642     0.698604  8.959224
# 2  61.720802  20.50   1.50  14.383937  ...   23.732955     0.091510  7.856259
# 3  87.996270   8.75   1.50  10.742463  ...    1.705186     0.037746  9.380633
# 4  83.637107   5.00   0.75   9.614828  ...   13.758863     0.001501  9.145333
#
#    MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF     HR_LF      HR_HF    HF_VLF  \
# 0              1.092856e+07  0.134410  0.249678   7.068440  0.033515
# 1             -1.039564e+06  0.125816  0.067484   5.971604  0.003921
# 2             -3.073518e+06  0.069888  0.038281  10.945519  0.003154
# 3             -4.341078e+06  0.094345  0.074014   2.435759  0.009692
# 4              1.311140e+07  0.076385  0.063323   3.259253  0.014438
#
#    subject_id  Condition Label
# 0          36                0
# 1          33                0
# 2          28                0
# 3          32                1
# 4          28                1
#
# [5 rows x 64 columns]

# %%
#combining both datasets and shuffle
dfs = [X_wesad, swell_x]
random.shuffle(dfs)
dfs=pd.concat(dfs, axis=0)
dfs
# Out:
#             MEAN_RR    MEDIAN_RR        SDRR      RMSSD       SDSD  \
# 0        660.756625   657.242305   34.857082   7.408307   7.408129
# 1        762.004543   769.028815  106.035926  13.591780  13.580221
# 2        978.587122   973.028365   80.323113  20.318045  20.316451
# 3        690.333891   669.548460   79.677822  15.173680  15.173087
# 4        724.270331   721.597785   71.663062  13.580379  13.580370
# ...             ...          ...         ...        ...        ...
# 391633   790.421530   794.457970   50.172724  11.029840  11.028626
# 391634   819.584353   832.239875  141.689319  14.689652  14.689246
# 391635   809.148374   808.486885   63.859615  13.886357  13.886357
# 391636  1001.883049  1033.107000  141.446770  17.956429  17.956289
# 391637   778.186980   724.357530  153.533010  12.112575  12.112571
#
#         SDRR_RMSSD         HR      pNN25     pNN50        SD1  ...  \
# 0         4.705134  91.050077   1.750000  0.000000   5.244915  ...
# 1         7.801475  80.267696   6.000000  1.000000   9.614723  ...
# 2         3.953289  61.720802  20.500000  1.500000  14.383937  ...
# 3         5.251055  87.996270   8.750000  1.500000  10.742463  ...
# 4         5.276956  83.637107   5.000000  0.750000   9.614828  ...
# ...            ...        ...        ...       ...        ...  ...
# 391633    4.548817  76.233611   2.200000  0.266667   7.801019  ...
# 391634    9.645519  75.479391   6.066667  1.466667  10.390332  ...
# 391635    4.598731  74.621671   7.066667  0.000000   9.822414  ...
# 391636    7.877222  61.249311  14.466667  1.333333  12.701251  ...
# 391637   12.675506  79.678193   4.733333  0.000000   8.567739  ...
#
#         SD1_BOXCOX  KURT_SQUARE   HR_SQRT  MEAN_RR_MEAN_MEAN_REL_RR    SD2_LF  \
# 0         2.184257     4.784952  9.542016              1.092856e+07  0.134410
# 1        12.244642     0.698604  8.959224             -1.039564e+06  0.125816
# 2        23.732955     0.091510  7.856259             -3.073518e+06  0.069888
# 3         1.705186     0.037746  9.380633             -4.341078e+06  0.094345
# 4        13.758863     0.001501  9.145333              1.311140e+07  0.076385
# ...            ...          ...       ...                       ...       ...
# 391633    0.817539     1.023535  8.731186              3.411073e+06  0.185744
# 391634   63.278931     0.165808  8.687888             -6.636711e+06  0.247628
# 391635    0.624739     0.092308  8.638384              2.099751e+08  0.075939
# 391636    1.493091     0.316769  7.826194             -1.299594e+07  0.166404
# 391637    2.097526     0.093729  8.926264              2.168873e+08  0.489424
#
#            HR_LF      HR_HF    HF_VLF  subject_id  Condition Label
# 0       0.249678   7.068440  0.033515          36                0
# 1       0.067484   5.971604  0.003921          33                0
# 2       0.038281  10.945519  0.003154          28                0
# 3       0.074014   2.435759  0.009692          32                1
# 4       0.063323   3.259253  0.014438          28                1
# ...          ...        ...       ...         ...              ...
# 391633  0.200779   2.994731  0.041512          23                1
# 391634  0.093403   3.016309  0.004722          13                0
# 391635  0.063121   4.801703  0.017767           2                1
# 391636  0.051054  12.142254  0.001985          10                1
# 391637  0.179741   1.865973  0.015935          19                0
#
# [527288 rows x 64 columns]

# %%
# show number of instances per subject
dfs['subject_id'].value_counts()
# Out:
# subject_id
# 16    21502
# 6     20888
# 19    19920
# 14    19680
# 12    19680
# 10    19680
# 4     19440
# 2     19395
# 1     19179
# 17    18824
# 18    18603
# 5     18050
# 7     17571
# 21    16679
# 13    16080
# 24    16080
# 3     16015
# 9     15942
# 22    15269
# 25    14915
# 20    14759
# 23    13487
# 34     9352
# 40     9350
# 38     9150
# 35     9139
# 36     9135
# 39     9096
# 37     9041
# 29     9005
# 32     8997
# 30     8981
# 31     8970
# 28     8956
# 33     8921
# 27     8868
# 26     8689
# Name: count, dtype: int64

# %%
# Load the data into a pandas DataFrame
df = dfs
# Define the group column (subject IDs)
group_col = 'subject_id'
# Define the test size (30%)
test_size = 0.3
# Initialize empty lists to store the training and test data
X_train = []
X_test = []
y_train = []
y_test = []
# Split the data by subject ID and combine the training data
for group_id, group_data in df.groupby(group_col):
    # Split the group data into training and test sets
    X_group_train, X_group_test, y_group_train, y_group_test = train_test_split(
        group_data.iloc[:, :-2],  # features only
        group_data.iloc[:, -1],   # label only
        test_size=test_size,      # test size ~= 30%
        random_state=123,stratify=group_data.iloc[:, -1] # for reproducibility
    )
    # Append the training and test data to the respective lists
    X_train.append(X_group_train)
    X_test.append(X_group_test)
    y_train.append(y_group_train)
    y_test.append(y_group_test)

# # PART BELOW IS FOR TRAINNG MODELS AND SELECTING THE BEST MODEL

# #####################################################################################################

# # Combine the training data from all subjects
# X_train = pd.concat(X_train)
# y_train = pd.concat(y_train)
# # select top 8 features using mRMR
# selected_features = mrmr_classif(X=X_train, y=y_train, K=8)
# print(selected_features)
# x_train=X_train[selected_features]


# # Define the k-fold cross-validation object
# kfold = StratifiedKFold(n_splits=15, shuffle=True,random_state=123)
# best_model = None
# best_score = 0
# # Train the model using k-fold cross-validation
# model = GradientBoostingClassifier(max_depth=20, min_samples_split=2, n_estimators=100)
# # Train and validate the model using k-fold cross-validation
# for train_index, val_index in kfold.split(x_train,y_train):
#     X_train_kf, X_val = np.array(x_train)[train_index], np.array(x_train)[val_index]
#     y_train_kf, y_val = np.array(y_train)[train_index], np.array(y_train)[val_index]
#     # Fit the model on the training set and the validation set
#     model.fit(X_train_kf, y_train_kf)
#     # Compute the score on the validation set
#     y_pred_val = model.predict(X_val)
#     val_score = accuracy_score(y_val, y_pred_val)
#     print(f"Validation score: {val_score:.4f}")
#     # Save the model if it is the best one so far
#     if val_score > best_score:
#         best_score = val_score
#         best_model = model

# #####################################################################################################

# # CODE BLOCK BELOW IS PRINTING CLASSIFICATION REPORT FOR EACH SUBJECT INDIVIDUALLY

# # Iterate over the test data for each subject and evaluate the model
# for i in range(len(X_test)):
#     # Evaluate the model on the test data for the i-th subject
#     y_pred = best_model.predict(X_test[i][selected_features])
#     test_score = accuracy_score(y_test[i], y_pred)
#     print(f"Test score for subject {i+1}: {test_score:.4f}")
#     # Compute the precision, recall, and F1 score for each class
#     report = classification_report(y_test[i], y_pred)
#     print(f"Classification report for subject {i+1}:\n{report}\n")
# # End the timer
# end_time = time.time()
# # Calculate the computational time
# computational_time = end_time - start_time
# print("Computational time:", computational_time)

# #####################################################################################################

# %% [markdown]
# # Block below is only for first time execution (now the best model is already saved and being loaded in the following code block)

# %%
# # print("Computational time:", computational_time)

# # Save the best model and selected features
# import joblib
# import pickle

# # Save the model using joblib (better for large NumPy arrays and scikit-learn models)
# joblib.dump(best_model, 'best_model.joblib')

# # Save the selected features using pickle
# with open('selected_features.pkl', 'wb') as f:
#     pickle.dump(selected_features, f)

# print("Model and features saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       5 import pickle
#       7 # Save the model using joblib (better for large NumPy arrays and scikit-learn models)
# ----> 8 joblib.dump(best_model, 'best_model.joblib')
#      10 # Save the selected features using pickle
#      11 with open('selected_features.pkl', 'wb') as f:
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# # LOAD THE MODEL AND PERFORM PREDICTIONS

# %%
import joblib
import pickle
import numpy as np
from sklearn.metrics import classification_report, accuracy_score

# Load the saved model and features
model_path = '/kaggle/input/wesad-swell-binary-stress-best-model/WESAD_SWELL_BINARY_BEST_MODEL/best_model.joblib'
features_path = '/kaggle/input/wesad-swell-binary-stress-best-model/WESAD_SWELL_BINARY_BEST_MODEL/selected_features.pkl'

loaded_model = joblib.load(model_path)
with open(features_path, 'rb') as f:
    selected_features = pickle.load(f)

# Initialize lists for all predictions and true labels
all_predictions = []
all_true_labels = []

# Make predictions for each test subject and collect results
for i in range(len(X_test)):
    # Get predictions for current subject using selected features
    y_pred = loaded_model.predict(X_test[i][selected_features])
    
    # Collect predictions and true labels
    all_predictions.extend(y_pred)
    all_true_labels.extend(y_test[i])

# Convert lists to numpy arrays
all_predictions = np.array(all_predictions)
all_true_labels = np.array(all_true_labels)


# Print sample counts
print(f"\nTotal number of test samples: {len(all_true_labels)}")
print(f"\nTotal number of predictions: {len(all_predictions)}")
# for i in range(len(X_test)):
#     print(f"Subject {i+1} test samples: {len(X_test[i])}")
    
# Calculate and print overall accuracy
overall_accuracy = accuracy_score(all_true_labels, all_predictions)
print(f"\nOverall Test Accuracy: {overall_accuracy:.4f}")

# Generate and print consolidated classification report
consolidated_report = classification_report(all_true_labels, all_predictions)
print(f"\nConsolidated Classification Report:\n{consolidated_report}")

# Calculate computational time
# end_time = time.time()
# computational_time = end_time - start_time
# print(f"\nComputational time: {computational_time:.2f} seconds")
# Out:
# Total number of test samples: 158199
#
# Total number of predictions: 158199
#
# Overall Test Accuracy: 0.9989
#
# Consolidated Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     92137
#            1       1.00      1.00      1.00     66062
#
#     accuracy                           1.00    158199
#    macro avg       1.00      1.00      1.00    158199
# weighted avg       1.00      1.00      1.00    158199
